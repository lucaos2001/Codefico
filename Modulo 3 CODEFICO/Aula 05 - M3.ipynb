# %% [markdown]
# # Questão 1
#
# Considere o esquema ER COMPANHIA_AEREA da Figura 3.21 e suponha que seja necessário registrar diferentes tipos de TRECHOS (ponte aérea, internacional e nacional) e que os trechos de ponte aérea terão que registrar um Código ANAC (observe que um voo pode ser de ponte aérea e nacional). Suponha que também se deseje registrar cada uma das aeronaves como sendo ou de voos comerciais ou de voos fretados. Se for fretado, deve contar a informação do número de autorização. O DEER com os novos elementos foi feito como atividade da Aula 3 - Módulo 3. A solução do professor está abaixo.
#
# Analise o diagrama resultante e utilize o algoritmo estudado em aula para geração do diagrama de esquema relacional a partir do DEER.
#
#
# ![Captura de tela 2023-08-22 142435.png](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-08-23 at 15.10.27.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Resposta Questão 1:

# %% [markdown]
# # Questão 2
#
# A narrativa a seguir descreve uma versão simplificada da organização das instalações olímpicas planejadas para os Jogos Olímpicos de verão. Foi feito o DEER como atividade prática da Aula 3 - Módulo 3. A solução do professor está abaixo.
#
# Analise o DEER resultante e utilize o algoritmo estudado em aula para geração do diagrama de esquema relacional a partir do DEER.
#
# - As instalações olímpicas são divididas em complexos esportivos, os quais são divididos em tipos de um esporte e poliesportivo.
#
# - Os complexos poliesportivos possuem áreas designadas para cada esporte com um indicador de localização (por exemplo, centro, canto NE, e assim por diante).
#
# - Um complexo tem um local, organizador-chefe, área total ocupada, e assim por diante.
#
# - Um complexo mantém uma série de eventos (por exemplo, o estádio com raias pode englobar muitas corridas diferentes).
#
# - Para cada evento existe uma data planejada, duração, número de participantes, número de oficiais e assim por diante.
#
# - Uma relação de todos os oficiais será mantida com a lista dos eventos em que cada oficial estará envolvido.
#
# - Diferentes equipamentos são necessários para os eventos (por exemplo, balizas, postes, barras paralelas), bem como para a manutenção. Os dois tipos de instalações (um esporte e poliesportivo) terão diferentes tipos de informação. Para cada tipo, o número de instalações necessárias é mantido, com um orçamento aproximado.

# %% [markdown]
# ![WhatsApp Image 2023-08-23 at 15.36.07.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # Resposta Questão 2:

# %% [markdown]
# # Questão 3
#
# Considere o projeto de software que você propôs na Aula 1 do Módulo 3. Na aula 3, você desenvolveu o modelo conceitual do seu banco ao fazer o DER Estendido da aplicação do seu projeto.
#
# Analise o DEER feito e utilize o algoritmo estudado em aula para geração do diagrama de esquema relacional a partir do DEER.

# %% [markdown]
# # Resposta Questão 3:
