# %% [markdown]
# ![cabeçalho_notebooks.png](data:image/png;base64,...)

# %% [markdown]
# ###**Parte 1: Exercícios com o Pipe (|) e Editor de Texto no Terminal**
#
# **Passo 1.1**: Criar o arquivo "contador.py" usando o Vim.
#
# No terminal, execute o seguinte comando para criar o arquivo "contador.py" usando o Vim:
#
# ```bash
# vim contador.py
# ```
#
# Isso abrirá o Vim no modo de edição.
#
# **Passo 1.2**: Escrever um programa simples em "contador.py".
#
# Dentro do Vim, pressione "i" para entrar no modo de inserção e escreva o programa Python simples. Por exemplo:
#
# ```python
# print("Linha 1")
# print("Linha 2")
# print("Linha 3")
# print("Linha 4")
# print("Linha 5")
# ```
#
# Depois de escrever o programa, pressione "Esc" para sair do modo de inserção e, em seguida, digite `:wq` e pressione "Enter" para salvar e sair do Vim.
#
# **Passo 1.3**: Executar o programa e contar as linhas com o `wc -l`.
#
# Agora, execute o programa Python usando o seguinte comando:
#
# ```bash
# python contador.py
# ```
#
# Isso imprimirá as cinco linhas de texto no terminal. Em seguida, use o pipe `|` para redirecionar a saída para o comando `wc -l`, que contará as linhas:
#
# ```bash
# python contador.py | wc -l
# ```
#
# Você verá a saída que mostra o número de linhas impressas pelo programa Python, que deve ser "5".

# %% [markdown]
# **Passo 1.1**<br>
# **Passo 1.2**<br>
# ![image.png](attachment:image.png)
#
# **Passo 1.3**<br>
# ![image-2.png](attachment:image-2.png)
#
# Execução do programa:
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ###**Parte 2: Exercícios com o Editor de Texto e Gerenciamento de Processos**
#
#
# **Passo 2.1**: Criar o arquivo "loop_infinito.py" usando o Vim.
#
# No terminal, execute o seguinte comando para criar o arquivo "loop_infinito.py" usando o Vim:
#
# ```bash
# vim loop_infinito.py
# ```
#
# Isso abrirá o Vim no modo de edição.
#
# **Passo 2.2**: Escrever um programa Python em "loop_infinito.py".
#
# Dentro do Vim, pressione "i" para entrar no modo de inserção e escreva um programa Python que execute um loop infinito e imprima uma mensagem repetidamente. Por exemplo:
#
# ```python
# import time
#
# while True:
#     print("Mensagem repetida")
#     time.sleep(1)  # Aguarda 1 segundo entre cada mensagem
# ```
#
# Depois de escrever o programa, pressione "Esc" para sair do modo de inserção e, em seguida, digite `:wq` e pressione "Enter" para salvar e sair do Vim.
#
# **Passo 2.3**: Executar o programa em uma janela do terminal.
#
# Em uma janela do terminal, execute o programa Python recém-criado usando o seguinte comando:
#
# ```bash
# python loop_infinito.py
# ```
#
# O programa começará a imprimir a mensagem repetidamente no terminal.
#
# **Passo 2.4**: Encontrar o PID do processo "loop_infinito.py".
#
# Em outra janela do terminal, você pode usar o comando `ps` para listar todos os processos em execução e encontrar o PID do processo "loop_infinito.py". Use o comando a seguir:
#
# ```bash
# ps aux | grep loop_infinito.py
# ```
#
# Você verá uma saída que incluirá informações sobre o processo, incluindo seu PID.
#
# **Passo 2.5**: Usar o comando "kill" para interromper o processo "loop_infinito.py".
#
# Com o PID encontrado no passo anterior, você pode usar o comando `kill` para interromper o processo "loop_infinito.py". Substitua `<PID>` pelo PID real encontrado:
#
# ```bash
# kill <PID>
# ```
#
# Isso enviará um sinal para interromper o processo e ele será encerrado.
#
# Lembre-se de que um loop infinito pode exigir a interrupção forçada usando o `kill -9 <PID>` se ele não responder à interrupção normal. Certifique-se de encerrar o processo com cuidado, pois o sinal de interrupção pode causar a perda de dados não salvos em outros programas.

# %% [markdown]
# **Passo 2.1**<br>
# ![image.png](attachment:image.png)
#
# **Passo 2.2**<br>
# ![image-2.png](attachment:image-2.png)
#
# **Passo 2.3**<br>
# ![image-3.png](attachment:image-3.png)
#
# **Passo 2.4**<br>
# ![image-4.png](attachment:image-4.png)
#
# **Passo 2.5**<br>
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
# ![image-8.png](attachment:image-8.png)
#
# Podemos usar também as teclas ctrl + c para interromper o loop.<br>
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ###**Parte 3: Exercício Calculadora com Pipe, Redirecionamento de Saída e Gerenciamento de Processos**
#
# **Passo 3.1**: Crie o arquivo "calculadora.py" usando o Vim:
#
# No terminal, execute o seguinte comando para criar o arquivo "calculadora.py" usando o Vim:
#
# ```bash
# vim calculadora.py
# ```
#
# **Passo 3.2**: Escreva um programa Python em "calculadora.py" que permita ao usuário realizar operações de adição, subtração, multiplicação e divisão. Peça ao usuário que insira dois números e a operação desejada.
#
# ```python
# # calculadora.py
#
# # Solicita ao usuário que insira dois números e a operação desejada.
# num1 = float(input("Digite o primeiro número: "))
# num2 = float(input("Digite o segundo número: "))
# operacao = input("Digite a operação (+, -, *, /): ")
#
# # Realiza a operação e exibe o resultado.
# if operacao == "+":
#     resultado = num1 + num2
# elif operacao == "-":
#     resultado = num1 - num2
# elif operacao == "*":
#     resultado = num1 * num2
# elif operacao == "/":
#     resultado = num1 / num2
# else:
#     print("Operação inválida")
#     resultado = None
#
# # Exibe o resultado apenas se não for None.
# if resultado is not None:
#     print("Resultado:", resultado)
# ```
#
# **Passo 3.3**: Salve e saia do Vim pressionando "Esc" e digitando `:wq` e pressionando "Enter".
#
# **Passo 3.4**: Execute o programa Python:
#
# ```bash
# python calculadora.py
# ```
#
# **Passo 3.5**: Use o pipe (|) para redirecionar a saída para o comando "grep" para filtrar apenas o resultado e redirecionar essa saída para um arquivo chamado "saida.txt":
#
# ```bash
# python calculadora.py | grep "Resultado" > saida.txt
# ```
#
# Isso executará o programa, filtrará apenas a linha que contém o resultado e salvará essa linha no arquivo "saida.txt".
#
# **Passo 3.6**: Em outra janela do terminal, use o comando "ps" para listar todos os processos em execução e encontre o PID do processo "calculadora.py":
#
# ```bash
# ps aux | grep calculadora.py
# ```
#
# **Passo 3.7**: Use o comando "kill" com o PID encontrado para interromper o processo "calculadora.py". Substitua `<PID>` pelo PID real encontrado:
#
# ```bash
# kill <PID>
# ```
#
# Isso interromperá o processo da calculadora Python que está em execução.

# %% [markdown]
# **Passo 3.1**<br>
# ![image.png](attachment:image.png)
#
# **Passo 3.2**<br>
# ![image-2.png](attachment:image-2.png)
#
# **Passo 3.3**<br>
# ![image-3.png](attachment:image-3.png)
#
# **Passo 3.4**<br>
# ![image-4.png](attachment:image-4.png)
#
# **Passo 3.5**<br>
# ![image-5.png](attachment:image-5.png)
#
# **Passo 3.6**<br>
# ![image-6.png](attachment:image-6.png)
#
# **Passo 3.7**<br>
# ![image-7.png](attachment:image-7.png)
