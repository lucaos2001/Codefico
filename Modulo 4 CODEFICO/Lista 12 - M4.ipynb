# %% [markdown]
# ![cabeçalho_notebooks.png](data:image/png;base64,...)

# %% [markdown]
# **Exercício 1: Acesse a vm1.codefico1.software usando o ssh que você recebeu em seu email**
#
# **Exercício 2: Mude a senha**
#
# **Exercício 3: Crie um par de chaves RSA e cadastre no servidor**
#
# **Exercício 4:Faça a configuração do .ssh/config criando um host**
#
# **Exercício 5: Suba uma aplicação UDP na máquina da digitalocean (servidor) e faça um cliente local para comunicar com o servidor**

# %% [markdown]
# ![image.png](attachment:image.png)
#
# **Criação das chaves RSA**
# ![image-2.png](attachment:image-2.png)
#
# Chaves cadastradas no servidor da digital ocean<br>
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# **Configuração**<br>
# ![image-6.png](attachment:image-6.png)
# ![image-5.png](attachment:image-5.png)
