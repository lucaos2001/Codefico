# %% [markdown]
# ![cabeçalho_notebooks.png](data:image/png;base64,...)

# %% [markdown]
# **Passo 1**: Coloque o arquivo `tabela-a.csv` na pasta pessoal (`~`). Você pode fazer isso manualmente copiando o arquivo `tabela-a.csv` para a sua pasta pessoal.
#
# **Passo 2**: Crie uma pasta chamada `execução` e entre nela. Você pode fazer isso no terminal com os seguintes comandos:
#
# ```bash
# mkdir ~/execução
# cd ~/execução
# ```
#
# **Passo 3**: Crie um programa Python chamado `recalculate.py` para recalcular a pontuação e salvar a tabela recalculada. Use um editor de texto para criar um arquivo chamado `recalculate.py` e adicione o seguinte código:
#
# ```python
# import csv
#
# # Função para recalcular a pontuação total
# def recalcular_pontuacao(row):
#     vitorias = int(row['Vitorias'])
#     empates = int(row['Empates'])
#     derrotas = int(row['Derrotas'])
#     return vitorias * 3 + empates - derrotas
#
# # Leitura do arquivo CSV original
# with open('tabela.csv', 'r') as arquivo:
#     leitor = csv.DictReader(arquivo)
#     cabecalho = leitor.fieldnames
#
#     # Lista para armazenar as linhas recalculadas
#     linhas_recalculadas = []
#
#     for linha in leitor:
#         # Recalcula a pontuação e adiciona à lista
#         linha['Pontuacao'] = recalcular_pontuacao(linha)
#         linhas_recalculadas.append(linha)
#
# # Escrita do arquivo recalculado
# with open('tabela_recalculada.txt', 'w') as arquivo_saida:
#     # Escreve o cabeçalho
#     arquivo_saida.write(','.join(cabecalho) + '\n')
#
#     # Escreve as linhas recalculadas
#     for linha in linhas_recalculadas:
#         # Converter os valores inteiros em strings antes de escrever
#         linha_str = [str(valor) for valor in linha.values()]
#         arquivo_saida.write(','.join(linha_str) + '\n')
#
# ```
#
# **Passo 4**: Crie um script Python chamado `check_existence.py` para verificar a existência do arquivo `tabela-a_recalculada.txt`. Use um editor de texto para criar um arquivo chamado `check_existence.py` um exemplo do código:
#
# ```python
# import os
# import subprocess
#
# # Verifica se o arquivo tabela-a_recalculada.txt existe
# if not os.path.exists('tabela_recalculada.txt'):
#     # Se não existe, execute o programa Python
#     print("Rodando recalculate")
#     subprocess.run(["python3", "recalculate.py"])
#
#     # Ordene o resultado usando o comando sort com o Pipe e a opção -n
#     subprocess.run(["sort", "-t,", "-k5,5n", "tabela_recalculada.txt", "-o", "tabela_recalculada.txt"])
# else:
#     print("O arquivo tabela-a_recalculada.txt já existe.")
#
#
# ```
#
# **Passo 5**: Se o arquivo `tabela-a_recalculada.txt` não existir, execute o programa Python criado no Passo 3 e ordene o resultado com base na coluna de pontuação (P) usando o comando `sort` com a opção `-n`. Salve o resultado ordenado em `tabela-a_recalculada.txt`. Você pode fazer isso com os seguintes comandos no terminal:
#
# ```bash
# python recalculate.py  # Executa o programa Python para recalcular a pontuação
# sort -t, -k5,5n tabela_recalculada.txt -o tabela_recalculada.txt  # Ordena e salva o resultado
# ```
#
# **Passo 6**: Se o arquivo `tabela-a_recalculada.txt` existir, você pode verificar isso executando o script Python criado no Passo 4:
#
# ```bash
# python check_existence.py
# ```

# %% [markdown]
# **Passo 1**<br>
# mv tabela-a.csv ~
#
# **Passo 2**<br>
# ![image.png](attachment:image.png)
#
# **Passo 3**<br>
# ![image-2.png](attachment:image-2.png)<br>
# ![image-3.png](attachment:image-3.png)
#
# **Passo 4**<br>
# ![image-5.png](attachment:image-5.png)
# ![image-4.png](attachment:image-4.png)
#
# **Passo 5**<br>
#
# **Passo 6**<br>
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# Planilha de sugestão:
# [https://drive.google.com/file/d/1qehwlCqHPBhsFRRdFTe2kxs1rm_wIXoP/view?usp=sharing](https://)
