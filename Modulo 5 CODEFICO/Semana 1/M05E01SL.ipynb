# %% [markdown]
# ![modulo 5 header.png](data:image/png;base64,...)

# %% [markdown]
# ## Exercícios
#
# 1 - Pergunta: Qual é a finalidade da declaração <!DOCTYPE html> em um documento HTML? Qual é sua importância?
#
# 2 - Pergunta: O que são elementos HTML? Explique brevemente o conceito.
#
# 3 - Pergunta: Em HTML, como os elementos são estruturados geralmente? Descreva a estrutura básica de um documento HTML, incluindo as tags de abertura e fechamento.
#
# 4 - Pergunta: O que são atributos em HTML e onde eles são normalmente encontrados em um elemento HTML? Dê um exemplo de um elemento HTML com atributos.
#
# 5 - Pergunta: O que são elementos vazios em HTML? Forneça alguns exemplos de elementos vazios e explique por que eles são considerados vazios.
#
# 6 - Pergunta: Explique a diferença entre elementos de bloco e elementos inline em HTML. Dê exemplos de cada um.
#
# 7 - Pergunta: Qual é a diferença entre as tags \<div> e \<span> em HTML? Quando você usaria uma em vez da outra?
#
# 8 - Pergunta: Qual atributo HTML permite abrir um link em uma nova janela ou guia do navegador? Dê um exemplo de como usar esse atributo.
#
# 9 - Pergunta: Além do exemplo mencionado na aula, pesquise e liste pelo menos três meta informações que podem ser adicionadas a uma página HTML. Explique brevemente o propósito de cada uma delas.
#
# 10 - Pergunta: Além das tags \<b> e \<i>, que outras tags de formatação HTML você conhece? Liste pelo menos duas tags adicionais e explique como elas são usadas.

# %% [markdown]
# **RESPOSTAS**
#
# **1 -** Tem a finalidade de definir a versão HTML que está sendo usada e informa ao navegador qual a especificação ou padrão a ser seguido ao renderizar a página. Garante a interpretação correta e garante a consistência na renderização da página em diferentes navegadores.<br><br>
# **2 -** Elementos HTML são os componentes fundamentais de uma página cuja função é estruturar e exibir o conteúdo.Os elementos são aqueles que possuem chave "<>".<br><br>
# **3 -** São estruturados de forma hierárquica. O HTML começa com a tag básica que é "!DOCTYPE" é uma tag de auto-fechamento que é usada para definir a versão do html que está sendo usada.Temos a tag "head", é uma tag que necessita de uma tag de fechamento, o "head" é onde contém informações sobre o documento e que não exibidas diretamente na página web.Temos o elemento "body" que também necessita de sua tag de fechamento, e é onde contém o conteúdo que será exibido na página.<br><br>
# **4 -** Os atributos são informações adicionais que são passadas dentro da tag de abertura para manipular um elemento.<br><br>![1.png](attachment:1.png)<br><br>
# **5 -** São elementos que não possuem conteúdo entre suas tags de abertura e fechamento, são de auto fechamento. São considerados vazios pois não possuem conteúdo adicional entre suas tags.<br><br>A tag "br" é utilizada para dar uma quebra de linha.<br>A tag "img" é utilizada para adicionar uma imagem a página HTML.![br.png](attachment:br.png)<br><br>
# **6 -** Os elementos em bloco são utilizados para criar divisões ou blocos de conteúdo podendo abranger uma grande quantidade de conteúdo, uma característica dos elementos em bloco é que eles usam a linha inteira. Os elementos inline são utilizados na manipulação de elementos específicos dentro do código, uma característica dos elementos inline é que eles ocupam apenas o espaço necessário do texto, não ocupam a linha toda.<br><br>Codigos<br>![code1.png](attachment:code1.png)<br>![code2.png](attachment:code2.png)<br><br>
# **7 -** A tag "div" é usada para fazer divisões em blocos, além de ocupar uma linha inteira do html e a tag "span" é usada para fazer alterações em linha, e ocupa. A tag "div" teria mais utilidade sendo usada para fazer alterações de um bloco maior do código, já a tag "span" seria o contrário, não ocupa uma linha inteira ela seria mais util na manupulação de uma pequena e específica parte do html.<br><br>
# **8 -** Podemos utilizar a tag "a" e seu atributo "target" com o valor "_blank" que indicará que o link deve ser aberto em uma nova janela.<br><br>Codigo<br>![blank.png](attachment:blank.png)<br><br>
# **9 -** Temos a "description" ele possuí uma breve descrição sobre o conteúdo do site.<br>O "content-language" que é usado para definir a linguagem default do site.<br>O atributo "keywords" fornece uma lista de palavras chave que são relevantes para a página web.<br><br>
# **10 -** Temos a tag "strong" que deixa o texto em negrito, semelhante a tag "b" e também a tag "ins", que deixa o texto sublinhado.<br>A seguir mostro exemplo das tags em uma página web e o código.<br><br>
# Código<br>
# ![code-2.png](attachment:code-2.png) <br><br>
# Pagina web<br>
# ![Captura de tela 2023-10-16 150152.png](<attachment:Captura de tela 2023-10-16 150152.png>)

# %% [markdown]
# ## **Atividade Extra: Crie uma Home Page Completa**
#
# Nesta atividade extra, você terá a oportunidade de aplicar seus conhecimentos em HTML para criar uma página inicial (Home Page) completa. Utilize todos os elementos mencionados nas respostas da lista de exercícios anterior para construir sua página.
#
# **Instruções:**
#
# 1. **Estrutura Básica:** Comece criando a estrutura básica de um documento HTML. Certifique-se de incluir a declaração `<!DOCTYPE html>` e as tags `<html>`, `<head>` e `<body>`.
#
# 2. **Título:** No cabeçalho (`<head>`), adicione um título descritivo para sua página usando a tag `<title>`.
#
# 3. **Elementos de Texto:** Dentro do `<body>`, inclua parágrafos de texto (`<p>`) com informações sobre o conteúdo da sua página. Você pode ser criativo e escolher o tema da sua Home Page.
#
# 4. **Links:** Adicione pelo menos um link (`<a>`) que leva a outra página da web. Certifique-se de definir o atributo `href` para o endereço correto.
#
# 5. **Imagem:** Insira uma imagem (`<img>`) em sua página. Use o atributo `src` para especificar o caminho para a imagem e inclua um atributo `alt` para uma descrição alternativa.
#
# 6. **Elementos Vazios:** Inclua pelo menos um elemento vazio, como `<br>`, `<input>`, `<meta>`, ou `<link>`, explicando sua função no contexto da sua página.
#
# 7. **Formatação:** Aplique formatação apropriada usando tags de formatação HTML, como `<b>`, `<i>`, ou outras que você tenha pesquisado.
#
# Lembre-se de manter a estrutura organizada e bem formatada. Sinta-se à vontade para ser criativo com o conteúdo da sua Home Page, mas certifique-se de incluir todos os elementos mencionados acima.
#
# **Dica:** Você pode usar um editor de código HTML, como o Visual Studio Code, para criar sua página. Salve o arquivo com a extensão `.html`.
#
# Divirta-se criando sua Home Page e pratique seus conhecimentos em HTML!

# %%
<!DOCTYPE html>
<html>
<head>
    <title>Minha Página Web</title>
    <meta name="description" content="Exercício extra">
    <!--O <meta> foi usado apenas para adicionar uam breve descrição
    a respeito da minha página.-->
</head>
<body>
    <p>Página utilizada para</p>
    <p>mostrar o meu aprendizado</p>
    <p>na linguagem de <i>marcação</i> HTML</p>
    <a href="https://github.com/lucaos2001" target="_blank">Meu Portfólio</a><br>
    <!--O elemento <br> foi utilizado para poder dar um espaço
    entre o link do portfolio e a imagem, pois a imagem estava grudada na frente
    do link e não abaixo como eu gostaria.-->
    <img src="Captura de tela 2023-10-17 165817.png" alt="Foto do meu cachorro">
</body>
</html>

# %% [markdown]
# ![Captura de tela 2023-10-17 170856.png](<attachment:Captura de tela 2023-10-17 170856.png>)
