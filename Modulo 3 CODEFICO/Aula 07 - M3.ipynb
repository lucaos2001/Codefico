# %% [markdown]
# ![cabeçalho_notebooks.png](data:image/png;base64,...)

# %% [markdown]
# Crie um banco de dados chamado MUNDO e crie as seguintes tabelas dentro desse banco de dados.

# %% [markdown]
# **EXERCÍCIO 1**
#
# Faça a seguinte tabela(País):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Escreva seu código

# %% [markdown]
# **EXERCÍCIO 2**
#
# Faça a seguinte tabela(Cidade):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Escreva seu código

# %% [markdown]
# **EXERCÍCIO 3**
# Faça a seguinte tabela(Rio):

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Escreva seu código

# %% [markdown]
# **EXERCÍCIO 4**
#
# Faça as seguintes consultas, considerando que as tabelas montadas acima estão em um Banco de Dados chamado Mundo.
#
# 1. Liste todas as cidades e os países aos quais pertencem.
# 2. Liste todas as cidades que são capitais.
# 3. Liste todos os atributos dos países onde a expectativa de vida é menor que 70 anos.
# 4. Liste todas as capitais e as populações dos países cujos PIB é maior que 1 trilhão de dólares.
# 5. Quais é o nome e a população da capital do país onde o rio St. Lawrence tem sua nascente.
# 6. Qual é a média da população das cidades que não são capitais.
# 7. Para cada continente retorne o PIB médio de seus países.
# 8. Considerando os rios que nascem no USA, encontre o comprimento do menor rio.
# 9. Liste os países cujo PIB é maior que o PIB do Canada.

# %%
#Escreva seu código
