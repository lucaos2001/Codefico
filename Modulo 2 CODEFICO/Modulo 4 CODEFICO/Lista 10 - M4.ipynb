# %% [markdown]
# ![cabeçalho_notebooks.png](data:image/png;base64,...)

# %% [markdown]
# 1. Consultando informações de DNS:
#    - Use o comando `dig` para consultar as informações de DNS para o domínio "www.example.com".
#    - Use o comando `nslookup` para fazer a mesma consulta para o domínio "www.example.com".
#
# 2. Consultando tipos específicos de registros DNS:
#    - Use o comando `dig` para consultar o registro MX (Mail Exchanger) para o domínio "example.com".
#    - Use o comando `nslookup` para consultar o registro NS (Name Server) para o domínio "example.com".
#
# 3. Obtendo apenas o endereço IP de um domínio:
#    - Use o comando `dig +short` para obter o endereço IP do domínio "www.google.com".
#    - Use o comando `nslookup` para obter o mesmo resultado para o domínio "www.google.com".
#
# 4. Realizando uma pesquisa reversa:
#    - Use o comando `dig -x` para traduzir o endereço IP "8.8.8.8" em um nome de domínio.
#    - Use o comando `nslookup` para realizar a mesma pesquisa reversa para o endereço IP "8.8.8.8".
#
# 5. Consultando um servidor DNS específico:
#    - Use o comando `nslookup` para consultar um servidor DNS específico (por exemplo, "8.8.8.8") para obter informações sobre o domínio "www.example.com".
#
# 6. Praticando tradução de nomes de domínio para IPs:
#    - Use o comando `dig +short` para traduzir os seguintes domínios em endereços IP: "www.facebook.com", "www.twitter.com", "www.instagram.com".
#    - Use o comando `nslookup` para fazer o mesmo para os mesmos domínios.

# %% [markdown]
# Exemplos de uso dos comandos `dig` e `nslookup` para realizar consultas DNS e traduzir nomes de domínio em endereços IP:
#
# **Comando `dig` Exemplos**:
#
# 1. Consultar as informações de DNS para o domínio "www.google.com":
#    ```
#    dig www.google.com
#    ```
#
# 2. Consultar o registro MX (Mail Exchange) para o domínio "example.com":
#    ```
#    dig example.com MX
#    ```
#
# 3. Obter o endereço IP associado ao domínio "www.facebook.com":
#    ```
#    dig +short www.facebook.com
#    ```
#
# 4. Realizar uma pesquisa reversa para traduzir o endereço IP "8.8.8.8" em um nome de domínio:
#    ```
#    dig -x 8.8.8.8
#    ```
#
# **Comando `nslookup` Exemplos**:
#
# 1. Consultar as informações de DNS para o domínio "www.microsoft.com":
#    ```
#    nslookup www.microsoft.com
#    ```
#
# 2. Consultar o servidor DNS do Google (8.8.8.8) para obter informações sobre o domínio "www.apple.com":
#    ```
#    nslookup www.apple.com 8.8.8.8
#    ```
#
# 3. Realizar uma pesquisa reversa para traduzir o endereço IP "208.67.222.222" em um nome de domínio:
#    ```
#    nslookup 208.67.222.222
#    ```
#
# 4. Traduzir o nome de domínio "www.example.com" em um endereço IP:
#    ```
#    nslookup www.example.com
#    ```
# 5. Consultar o registro NS (Name Server) para o domínio "example.com":
#    ```
#    nslookup -type=NS example.com
#    ```
# Estes são exemplos básicos de como usar os comandos `dig` e `nslookup` para consultar informações de DNS e traduzir entre nomes de domínio e endereços IP. Os resultados fornecidos pelas consultas podem incluir informações sobre servidores DNS, registros de recursos (como registros A, MX, CNAME, etc.) e muito mais, dependendo das consultas específicas realizadas.

# %% [markdown]
# **1**
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# **2**
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
#
# ![image-8.png](attachment:image-8.png)
#
# **3**<br>
# ![image-7.png](attachment:image-7.png)
#
# **4**<br>
# ![image-9.png](attachment:image-9.png)
# ![image-10.png](attachment:image-10.png)
#
# **5**<br>
# ![image-6.png](attachment:image-6.png)
#
# **6**<br>
# ![image-11.png](attachment:image-11.png)
# ![image-12.png](attachment:image-12.png)
# ![image-13.png](attachment:image-13.png)
