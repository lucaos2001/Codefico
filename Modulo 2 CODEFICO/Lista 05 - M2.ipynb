# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###Desafio:###
#
# Você é responsável por desenvolver um sistema de gerenciamento para uma academia. O sistema deve armazenar as informações dos membros em tuplas, contendo nome, idade, peso e altura. Além disso, o sistema deverá disponibilizar funcionalidades para exibir as pessoas com mais de 60 anos, calcular o Índice de Massa Corporal (IMC) de todos os membros, calcular a média de altura dos membros, exibir a pessoa mais leve e exibir o maior IMC.

# %% [markdown]
# **Passo 1:** Definir a Estrutura de Dados
#
# Crie uma lista vazia para armazenar as tuplas dos membros.
#
# Cada tupla conterá as informações de nome, idade, peso e altura do membro.

# %% [markdown]
# **Passo 2:** Implementar a Função de Cadastro de Novos Membros
#
# Crie uma função chamada cadastrar_membro que recebe o número de membros a serem cadastrados.
#
# Dentro da função, crie uma tupla que irá receber dados dos novos membros (nome, idade, peso e altura) como parâmetros.
#
# Depois crie uma lista para receber as tuplas com os membros.
#
# Faça um loop a partir do número de membros para ler os dados dos membros como input e adicioná-los a lista um por um.
#
# Exiba uma mensagem confirmando o cadastro dos membros.
#
# A função deve retornar a lista de membros.

# %% [markdown]
# **Passo 3:** Implementar a Função de Exibição de Pessoas com Mais de 60 Anos
#
# Crie uma função chamada exibir_membros_mais_de_60_anos que receba a lista de membros.
#
# Percorra a lista de membros e verifique a idade de cada membro.
#
# Se a idade do membro for maior que 60 anos, exiba o nome do membro.

# %% [markdown]
# **Passo 4:** Implementar a Função de Cálculo da Média de Altura
#
# Crie uma função chamada calcular_media_altura que receba a lista de membros.
#
# A função deve calcular a média de altura de todos os membros.
#
# Percorra a lista de membros e some as alturas de todos os membros.
#
# Divida a soma total das alturas pelo número de membros para obter a média.
#
# Exiba a média de altura.

# %% [markdown]
# **Passo 5:** Implementar a Função de Exibição da Pessoa Mais Leve
#
# Crie uma função chamada exibir_pessoa_mais_leve que recebe a lista de membros.
#
# Percorra a lista de membros e encontre o membro com o menor peso.
#
# Exiba o nome e o peso do membro mais leve.

# %% [markdown]
# **Passo 6:** Implementar a Função de Cálculo do IMC de Todos os Membros
#
# Crie uma função chamada calcular_imc que recebe a lista de membros.
#
# A função deve calcular o IMC de cada membro.
#
# Fórmula do IMC = Peso/(Altura x Altura)
#
# Percorra a lista de membros e, para cada membro, calcule o IMC utilizando a fórmula fornecida.
#
# Crie uma lista para armazenar tuplas com o nome e IMC de cada membro.
#
# Retorne essa lista.

# %% [markdown]
# **Passo 7:** Implementar a Função de Exibição do maior IMC
#
# Crie uma função chamada exibir_maior_IMC que recebe a lista de IMCs retornada acima.
#
# Percorra a lista de IMC e encontre o membro com o maior IMC.
#
# Exiba o nome e o IMC da pessoa.

# %% [markdown]
# **Passo 8:**
# Implementar um Menu
#
# Crie um loop para que o menu continue sendo exibido após o usuário selecionar uma opção até que ele decida sair.
#
# Com base na escolha do usuário, chame a função correspondente à opção selecionada ou execute o código necessário. (Crie uma opção para sair do loop)
#
# Lembre-se de imprimir as opções a cada loop do menu.
#
# Use seus conhecimentos e criatividade para desenvolver o layout e funcionalidades do menu!

# %% [markdown]
# **Exemplo 1:**
#
# *Entrada:*
#
# Digite 1: para cadastrar membros;
#
# Digite 2: para exibir as pessoas com mais de 60 anos;
#
# Digite 3: para calcular a média de altura geral;
#
# Digite 4: para exibir a pessoa mais leve;
#
# Digite 5: para exibir os IMCs;
#
# Digite 6: para exibir o maior IMC da academia;
#
# Digite 0: para SAIR;
#
# Digite: **1**
#
# Digite o número de membros que deseja inserir: **3**
#
# Digite o nome:**Davi**
#
# Digite a idade:**20**
#
# Digite o peso:**67**
#
# Digite a altura:**1.74**
#
# Digite o nome:**Roger**
#
# Digite a idade:**66**
#
# Digite o peso:**75**
#
# Digite a altura:**1.78**
#
# Digite o nome:**Leticia**
#
# Digite a idade:**33**
#
# Digite o peso:**63**
#
# Digite a altura:**1.7**
#
# *Saída:*
#
# A função apenas realiza a inserção dos membros na lista e retorna essa lista.

# %% [markdown]
# **Exemplo 2:**
#
# *Entrada:*
#
# Digite 1: para cadastrar membros;
#
# Digite 2: para exibir as pessoas com mais de 60 anos;
#
# Digite 3: para calcular a média de altura geral;
#
# Digite 4: para exibir a pessoa mais leve;
#
# Digite 5: para exibir os IMCs;
#
# Digite 6: para exibir o maior IMC da academia;
#
# Digite 0: para SAIR;
#
# Digite: **2**
#
# *Saída:*
#
# Membros idosos:
#
# Roger

# %% [markdown]
# **Exemplo 3:**
#
# *Entrada:*
#
# Digite 1: para cadastrar membros;
#
# Digite 2: para exibir as pessoas com mais de 60 anos;
#
# Digite 3: para calcular a média de altura geral;
#
# Digite 4: para exibir a pessoa mais leve;
#
# Digite 5: para exibir os IMCs;
#
# Digite 6: para exibir o maior IMC da academia;
#
# Digite 0: para SAIR;
#
# Digite: **3**
#
# *Saída:*
#
# Média geral de altura:
#
# 1.74

# %% [markdown]
# **Exemplo 4:**
#
# *Entrada:*
#
# Digite 1: para cadastrar membros;
#
# Digite 2: para exibir as pessoas com mais de 60 anos;
#
# Digite 3: para calcular a média de altura geral;
#
# Digite 4: para exibir a pessoa mais leve;
#
# Digite 5: para exibir os IMCs;
#
# Digite 6: para exibir o maior IMC da academia;
#
# Digite 0: para SAIR;
#
# Digite: **4**
#
# *Saída:*
#
# Membro mais leve:
#
# Leticia

# %% [markdown]
# **Exemplo 5:**
#
# *Entrada:*
#
# Digite 1: para cadastrar membros;
#
# Digite 2: para exibir as pessoas com mais de 60 anos;
#
# Digite 3: para calcular a média de altura geral;
#
# Digite 4: para exibir a pessoa mais leve;
#
# Digite 5: para exibir os IMCs;
#
# Digite 6: para exibir o maior IMC da academia;
#
# Digite 0: para SAIR;
#
# Digite: **5**
#
# *Saída:*
#
# IMC dos membros:
#
# Nome: Davi - IMC: 22.13
#
# Nome: Roger - IMC: 23.67
#
# Nome: Leticia - IMC: 21.80

# %% [markdown]
# **Exemplo 6:**
#
# *Entrada:*
#
# Digite 1: para cadastrar membros;
#
# Digite 2: para exibir as pessoas com mais de 60 anos;
#
# Digite 3: para calcular a média de altura geral;
#
# Digite 4: para exibir a pessoa mais leve;
#
# Digite 5: para exibir os IMCs;
#
# Digite 6: para exibir o maior IMC da academia;
#
# Digite 0: para SAIR;
#
# Digite: **6**
#
# *Saída:*
#
# Membro com maior IMC:
#
# Roger

# %%
membros = []
def cadastrar_membro(membros_a_serem_cadastrados):
    

    for i in range(membros_a_serem_cadastrados):
        lista = []
        nome = input("Digite o nome: ")
        lista.append(nome)
        idade = int(input("Digite a idade: "))
        lista.append(idade)
        peso = float(input("Digite o peso: "))
        lista.append(peso)
        altura = float(input("Digite a altura: "))
        lista.append(altura)
        membros.append(tuple(lista))
        print(f"{nome} foi cadastrado(a) com sucesso!!")


def exibir_membros_mais_de_60_anos(membros):
    acima_dos_60 = []
    idade_idoso = 0
    for i in range(len(membros)):
        if membros[i][1] > 60:
            acima_dos_60.append(membros[i][0])
            idade_idoso = membros[i][1]
            print(f"Membros idosos:\n{membros[i][0]} com {idade_idoso}")
    

def calcular_media_altura(membros):
    media = 0
    for l in range(len(membros)):
        media += membros[l][3]
    media /= len(membros)
    print(f"A media das alturas é de: {media:.2f}")
    
def exibir_pessoa_mais_leve(membros):
    mais_leve = 99999999
    for l in range(len(membros)):
        if  membros[l][2] < mais_leve:
            mais_leve =  membros[l][2]

    print(f"A pessoa mais leve é o(a): {membros[l][0]} com {membros[l][2]}KG")

def calcular_imc(membros):
    imc_tupla = []
    
    for l in range(len(membros)):
        tup = []
        tup.append(membros[l][0])
        calculo = membros[l][2] / (membros[l][3]*membros[l][3])
        tup.append(calculo)
        print(f"Nome: {membros[l][0]} - IMC: {calculo:.2f}")
    
        imc_tupla.append(tuple(tup))

    return imc_tupla
        
def exibir_maior_IMC(membros):
    maior_imc = 0
    nome_maior = ""
    for i in range(len(membros)):
        calculo = membros[i][2] / (membros[i][3]*membros[i][3])
        if calculo > maior_imc:
            maior_imc = calculo
            nome_maior = membros[i][0]
    
    print("Membro com maior IMC:")
    print(f"{nome_maior} com {maior_imc}")

def menu():

    opcao = int(input('''
    #################################################################
    #   Digite 1: para cadastrar membros;                           #
    #   Digite 2: para exibir as pessoas com mais de 60 anos;       #
    #   Digite 3: para calcular a média de altura geral;            #
    #   Digite 4: para exibir a pessoa mais leve;                   #
    #   Digite 5: para exibir os IMCs;                              #
    #   Digite 6: para exibir o maior IMC da academia;              #
    #   Digite 0: para SAIR;                                        #
    #################################################################
    '''))

    return opcao

while True:
    opcao = menu()
    if opcao == 1:
        quantidade = int(input("Digite o número de membros que deseja inserir: "))
        mcad = cadastrar_membro(quantidade)
    elif opcao == 2:
        exibir_membros_mais_de_60_anos(membros)
    elif opcao == 3:
        calcular_media_altura(membros)
    elif opcao == 4:
        exibir_pessoa_mais_leve(membros)
    elif opcao == 5:
        cal = calcular_imc(membros)
    elif opcao == 6:
        exibir_maior_IMC(membros)
    elif opcao == 0:
        break
    else:
        print("Digite um dos números presentes no menu")

print('''
        @

####    #   ##     ##
#       #   # #   # #
####    #   #   #   #
#       #   #       #
#       #   #       #







''')
# Out:
# Davi foi cadastrado(a) com sucesso!!
# Roger foi cadastrado(a) com sucesso!!
# Leticia foi cadastrado(a) com sucesso!!
# Membros idosos:
# Roger com 66
# A media das alturas é de: 1.74
# A pessoa mais leve é o(a): Leticia com 63.0KG
# Nome: Davi - IMC: 22.13
# Nome: Roger - IMC: 23.67
# Nome: Leticia - IMC: 21.80
# Membro com maior IMC:
# Roger com 23.671253629592222
#
#         @
#
# ####    #   ##     ##
# #       #   # #   # #
# ####    #   #   #   #
# #       #   #       #
# #       #   #       #
